# %%
# Install Brian2 in Google Colab
# !pip install brian2
# Out:
# Collecting brian2
#   Downloading Brian2-2.8.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from brian2) (1.26.4)
# Requirement already satisfied: cython>=0.29.21 in /usr/local/lib/python3.11/dist-packages (from brian2) (3.0.11)
# Requirement already satisfied: sympy>=1.2 in /usr/local/lib/python3.11/dist-packages (from brian2) (1.13.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from brian2) (3.2.1)
# Requirement already satisfied: jinja2>=2.7 in /usr/local/lib/python3.11/dist-packages (from brian2) (3.1.5)
# Requirement already satisfied: setuptools>=61 in /usr/local/lib/python3.11/dist-packages (from brian2) (75.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from brian2) (24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.7->brian2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.2->brian2) (1.3.0)
# Downloading Brian2-2.8.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.7 MB/s eta 0:00:00
# Installing collected packages: brian2
# Successfully installed brian2-2.8.0.1

# %%
from brian2 import *
import numpy as np

# Simulation parameters
defaultclock.dt = 0.1*ms
duration = 1000*ms

# Neuron parameters (adjusted for spiking)
v_rest = -65 * mV
v_reset = -70 * mV  # Reset to hyperpolarized potential
v_thresh = -50 * mV  # Lowered threshold for spiking
tau_m = 10 * ms      # Faster membrane dynamics
R = 20 * Mohm        # Higher resistance for stronger voltage conversion

# Neuron equations (unit-corrected with R*I)
granule_eqs = '''
dv/dt = (v_rest - v + R*I)/tau_m : volt
I : amp
'''

purkinje_eqs = '''
dv/dt = (v_rest - v + R*I)/tau_m : volt
I : amp
'''

dcn_eqs = '''
dv/dt = (v_rest - v + R*I)/tau_m : volt
I : amp
'''

# Create neuron groups
granule_neurons = NeuronGroup(100, granule_eqs,
                             threshold='v > v_thresh',
                             reset='v = v_reset',
                             method='exact',
                             refractory=2*ms)  # Refractory period

purkinje_neurons = NeuronGroup(20, purkinje_eqs,
                              threshold='v > v_thresh',
                              reset='v = v_reset',
                              method='exact',
                              refractory=2*ms)

dcn_neurons = NeuronGroup(10, dcn_eqs,
                         threshold='v > v_thresh',
                         reset='v = v_reset',
                         method='exact',
                         refractory=2*ms)

# Synaptic connections
# Granule -> Purkinje (excitatory)
synapses_granule = Synapses(granule_neurons, purkinje_neurons,
                           on_pre='I += 1.0 * nA')  # Stronger current
synapses_granule.connect(p=0.3)  # 30% connectivity

# Purkinje -> DCN (inhibitory: subtracts current)
synapses_purkinje = Synapses(purkinje_neurons, dcn_neurons,
                            on_pre='I -= 1.5 * nA')  # Inhibition
synapses_purkinje.connect(p=0.5)

# Sensory input (rectified sine wave: no negative values)
sensory_input = TimedArray(
    np.abs(np.sin(2 * np.pi * 10 * np.arange(0, duration/ms, defaultclock.dt/ms))) * 4 * nA,
    dt=defaultclock.dt
)
granule_neurons.I = 'sensory_input(t) + 1.0 * nA * rand()'  # Strong noise

# Add excitatory input to DCN neurons (simulating mossy fiber collaterals)
mossy_to_dcn = PoissonGroup(10, rates=50*Hz)
syn_mossy_dcn = Synapses(mossy_to_dcn, dcn_neurons, on_pre='I += 0.8 * nA')
syn_mossy_dcn.connect(p=0.5)

# Initialize voltages
granule_neurons.v = v_rest
purkinje_neurons.v = v_rest
dcn_neurons.v = v_rest

# Monitors
granule_spikes = SpikeMonitor(granule_neurons)
purkinje_spikes = SpikeMonitor(purkinje_neurons)
dcn_spikes = SpikeMonitor(dcn_neurons)

# Run simulation
run(duration)

# Plot results
figure(figsize=(12, 9))

subplot(311)
plot(granule_spikes.t/ms, granule_spikes.i, '.k', markersize=2)
title('Granule Cells')
ylabel('Neuron Index')
ylim([0, 100])

subplot(312)
plot(purkinje_spikes.t/ms, purkinje_spikes.i, '.r', markersize=4)
title('Purkinje Cells')
ylabel('Neuron Index')
ylim([0, 20])

subplot(313)
plot(dcn_spikes.t/ms, dcn_spikes.i, '.b', markersize=6)
title('DCN Neurons (Motor Output)')
xlabel('Time (ms)')
ylabel('Neuron Index')
ylim([0, 10])

tight_layout()
show()
